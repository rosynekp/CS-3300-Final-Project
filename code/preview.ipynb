# %%
import pandas as pd

# %%
df = pd.read_csv('../data/US_youtube_trending_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177390 entries, 0 to 177389
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           177390 non-null  object
#  1   title              177390 non-null  object
#  2   publishedAt        177390 non-null  object
#  3   channelId          177390 non-null  object
#  4   channelTitle       177390 non-null  object
#  5   categoryId         177390 non-null  int64
#  6   trending_date      177390 non-null  object
#  7   tags               177390 non-null  object
#  8   view_count         177390 non-null  int64
#  9   likes              177390 non-null  int64
#  10  dislikes           177390 non-null  int64
#  11  comment_count      177390 non-null  int64
#  12  thumbnail_link     177390 non-null  object
#  13  comments_disabled  177390 non-null  bool
#  14  ratings_disabled   177390 non-null  bool
# ...

# %%
df.head(10)
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# 5  w-aidBdvZo8  I Haven't Been Honest About My Injury.. Here's...
# 6  uet14uf9NsE                           OUR FIRST FAMILY INTRO!!
# 7  ua4QMFQATco                                 CGP Grey was WRONG
# 8  SnsPZj91R7E  SURPRISING MY DAD WITH HIS DREAM TRUCK!! | Lou...
# 9  SsWHMAhshPQ  Ovi x Natanael Cano x Aleman x Big Soto - Veng...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg        Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A    Apex Legends          20
# ...

# %%
import json
# load data using Python JSON module
with open('../data/US_category_id.json','r') as f:
    data = json.loads(f.read())

# %%
# categories = pd.read_json('../data/US_category_id.json')
categories = pd.json_normalize(data, record_path=['items'])

# %%
categories.head(10)
# Out:
#                     kind                         etag  id     snippet.title  \
# 0  youtube#videoCategory  IfWa37JGcqZs-jZeAyFGkbeh6bc   1  Film & Animation
# 1  youtube#videoCategory  5XGylIs7zkjHh5940dsT5862m1Y   2  Autos & Vehicles
# 2  youtube#videoCategory  HCjFMARbBeWjpm6PDfReCOMOZGA  10             Music
# 3  youtube#videoCategory  ra8H7xyAfmE2FewsDabE3TUSq10  15    Pets & Animals
# 4  youtube#videoCategory  7mqChSJogdF3hSIL-88BfDE-W8M  17            Sports
# 5  youtube#videoCategory  0Z6uGkj97NgjD-X3pkA-nL18Hqk  18      Short Movies
# 6  youtube#videoCategory  K_-7stg0kIU7eUBOPUa6j5fqIMQ  19   Travel & Events
# 7  youtube#videoCategory  I3IL9xGIM3MsULlqR4tvCsEKv98  20            Gaming
# 8  youtube#videoCategory  D1W6tq5mMMCV0wtNxf9A6g9wWjU  21     Videoblogging
# 9  youtube#videoCategory  QMEBz6mxVdklVaq8JwesPEw_4nI  22    People & Blogs
#
#    snippet.assignable         snippet.channelId
# 0                True  UCBR8-60-B28hp2BmDPdntcQ
# ...
